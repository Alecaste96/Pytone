# %% [markdown]
# Abbiamo utilizzato lo schema della rete neurale precedente per fare un esempio in ambito calcistico.
# l' idea di fondo è quella di, a partire da numero di goal,assist,passaggi progressivi e tackel fatti da un numero finito di centrocampisti, andare a predirre il numero di goal e assist che un centrocampista farà nella stagione calcistica successiva.

# %%
import numpy as np
from keras import Sequential
from keras import layers

# Definizione del modello
model = Sequential()

# Strato d'ingresso (16 unità: 4 caratteristiche per 4 anni)
model.add(layers.Dense(units=64, input_shape=[16], activation='relu'))

# Strato nascosto
model.add(layers.Dense(units=32, activation='relu'))

# Strato di uscita (2 unità: una per goal, una per assist)
model.add(layers.Dense(units=2))

# Compilazione del modello
model.compile(loss='mean_squared_error', optimizer='adam')

# Dati  per 4 giocatori con 4 anni di dati
# Input: [goal_anno1, assist_anno1, passaggi_anno1, tackle_anno1, ..., tackle_anno4]
input_data = np.array([
    [1,4,183,36,3,7,261,58,3,11,231,63,6,6,214,49],  # Giocatore 1 Barella
    [1,0,190,67,0,2,82,39,2,1,140,44,2,2,132,59],  # Giocatore 2 Bennacer
    [1,0,58,37,0,0,43,7,1,2,97,36,0,1,83,25],  # Giocatore 3 Cataldi
    [1,3,137,25,1,1,85,40,2,0,231,79,1,1,170,33],  # Giocatore 4 Cristante
])

# Output: [goal_futuro, assist_futuro]
output_data = np.array([
    [2, 3],  # Previsione goal e assist Giocatore 1 Barella
    [2, 2], # Previsione goal e assist Giocatore 2 Bennacer
    [1, 0],   # Previsione goal e assist Giocatore 3 Cataldi
    [3, 4], # Previsione goal e assist Giocatore 4 Cristante
])

# Addestramento del modello
model.fit(x=input_data, y=output_data, epochs=1000)

# Previsione per un nuovo giocatore
new_player_data = np.array([[0,5,229,76,4,2,315,81,3,3,147,44,0,2,134,42]]) #Giocatore 5 Locatelli
prediction = model.predict(new_player_data)

print("Previsione goal e assist di Manuel Locatelli nella stagione 2023/24:", prediction)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step - loss: 403.0950
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 285.1109
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 198.6066
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 140.5511
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 99.8774
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 70.5724
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 48.1437
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 34.5129
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 28.6580
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 30.0881
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 35.6164
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 41.3320
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 44.4061
# Epoch 14/1000
# ...
