# %% [markdown]
# Ecco il primo esempio di rete neurale. Ciò ci è servito a comprendere,la struttura delle stesse e la gestione dei dati in INPUT/OUTPUT

# %%
from keras import*
from keras import Sequential
from keras import layers
import numpy as np

model=Sequential()

#input costituito da un unita
model.add(layers.Dense(units=3,input_shape=[1]))

#strato intermedio
model.add(layers.Dense(units=2))

#unita strato di uscita sono pari a 1

model.add(layers.Dense(units=1))

rete_input = np.array([1, 2, 3, 4, 5])
rete_output = np.array([3, 6, 9, 12, 15])

#creazione della rete (adam)

model.compile(loss='mean_squared_error',optimizer='adam')

#si allena con 6000 cicli e mi permette di ottenere il risultato atteso
model.fit(x=rete_input,y=rete_output,epochs=6000)

print(model.predict(np.array([6])))  # Converti la lista in array NumPy
print(model.predict(np.array([7])))  # Converti la lista in array NumPy
print(model.predict(np.array([8])))  # Converti la lista in array NumPy
# Out:
# Epoch 1/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - loss: 108.8119
# Epoch 2/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 108.6046
# Epoch 3/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 108.3981
# Epoch 4/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 108.1925
# Epoch 5/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 107.9879
# Epoch 6/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 107.7841
# Epoch 7/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 107.5813
# Epoch 8/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 107.3794
# Epoch 9/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 107.1784
# Epoch 10/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 106.9783
# Epoch 11/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 106.7792
# Epoch 12/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 106.5810
# Epoch 13/6000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 106.3838
# Epoch 14/6000
# ...
